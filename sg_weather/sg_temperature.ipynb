# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import mode

base_dir = "sg_weather/"

# Data downloaded from: https://data.gov.sg/search?groups=environment
data = pd.read_csv(base_dir + "surface-air-temperature-monthly-mean.csv")

data['month'] = pd.DatetimeIndex(data['month'])

display(data)
# Out:
#          month  mean_temp
# 0   1982-01-01       25.9
# 1   1982-02-01       27.1
# 2   1982-03-01       27.2
# 3   1982-04-01       27.0
# 4   1982-05-01       28.0
# ..         ...        ...
# 462 2020-07-01       27.9
# 463 2020-08-01       28.3
# 464 2020-09-01       27.5
# 465 2020-10-01       28.3
# 466 2020-11-01       27.2
#
# [467 rows x 2 columns]

# %%
plt.figure(figsize = (15, 5))
plt.plot(data['month'], data['mean_temp'])
plt.show()
