# %% [markdown]
# # PeekingDuck
#
# https://github.com/aisingapore/PeekingDuck

# %%
try:
    import peekingduck
except:
    # !pip install -q peekingduck
    import peekingduck

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tqdm
import imageio

# %%
# !peekingduck init

# %%
# https://motchallenge.net/data/MOT15/
#!wget https://motchallenge.net/data/MOT15.zip
#!unzip MOT15.zip

# %%
#!vim pipeline_config.yml

# %%
w = cv2.VideoWriter('venice-2-train.mp4', cv2.VideoWriter_fourcc(*'MP4V'), 30, [1920, 1080])

files = sorted(os.listdir("MOT15/train/Venice-2/img1"))

for f in files:
    im = cv2.imread(os.path.join("MOT15/train/Venice-2/img1", f))
    w.write(im)

w.release()

# %%
# !peekingduck run
# Out:
# 2023-01-03 06:08:35 peekingduck.declarative_loader  INFO:  Successfully loaded pipeline file.
# 2023-01-03 06:08:35 peekingduck.declarative_loader  INFO:  Initializing input.visual node...
# 2023-01-03 06:08:35 peekingduck.declarative_loader  INFO:  Config for node input.visual is updated to: 'source': venice-2-train.mp4
# 2023-01-03 06:08:35 peekingduck.pipeline.nodes.input.visual  INFO:  Input size: 1920 by 1080
# 2023-01-03 06:08:35 peekingduck.declarative_loader  INFO:  Initializing model.jde node...
# 2023-01-03 06:08:36 numexpr.utils  INFO:  NumExpr defaulting to 2 threads.
# 2023-01-03 06:08:38 peekingduck.pipeline.nodes.model.jdev1.jde_files.tracker  INFO:  JDE model loaded with the following configs:
# 	Model type: 864x480
# 	Input resolution: [864, 480]
# 	IOU threshold: 0.5
# 	NMS threshold: 0.4
# 	Score threshold: 0.5
# 	Min bounding box area: 200
# 	Track buffer: 30
# 2023-01-03 06:08:39 peekingduck.declarative_loader  INFO:  Initializing dabble.statistics node...
# ...

# %%
cap = cv2.VideoCapture("output/venice-2-train_230103_060842.mp4")
images = []
while True:
    success, frame = cap.read()
    if success == False:
        break
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    frame = cv2.resize(frame, (int(1920 / 3), int(1080 / 3)))

    images.append(frame)
cap.release()

print(len(images))
# Out:
# 600

# %%
imageio.mimsave("venice-2-train.gif", images[330:380], fps = 30)
